# %% [markdown]
# ## [Lendo arquivos csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)

# %%
# lendo arquivo csv
import pandas as pd

data_path = 'G:\\Meu Drive\\Cursos e Treinamentos\\Cientista de Dados\\Treinamento Python\\Aplicado a Big Data\\Aula 3 - 08032021 - Pandas\\sample-data\\csv\\'

data = pd.read_csv(data_path+'netflix_titles.csv')

# %%
# Visualizando os primeiros registros
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
data.describe(include='all') # Informa as colunas do dataset e dados a respeito delas
# Out:
#        show_id   type title                director                cast  \
# count     7787   7787  7787                    5398                7069
# unique    7787      2  7787                    4049                6831
# top         s1  Movie    3%  Raúl Campos, Jan Suter  David Attenborough
# freq         1   5377     1                      18                  18
# mean       NaN    NaN   NaN                     NaN                 NaN
# std        NaN    NaN   NaN                     NaN                 NaN
# min        NaN    NaN   NaN                     NaN                 NaN
# 25%        NaN    NaN   NaN                     NaN                 NaN
# 50%        NaN    NaN   NaN                     NaN                 NaN
# 75%        NaN    NaN   NaN                     NaN                 NaN
# max        NaN    NaN   NaN                     NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7280             7777   7787.000000   7780      7787
# unique            681             1565           NaN     14       216
# top     United States  January 1, 2020           NaN  TV-MA  1 Season
# freq             2555              118           NaN   2863      1608
# mean              NaN              NaN   2013.932580    NaN       NaN
# std               NaN              NaN      8.757395    NaN       NaN
# min               NaN              NaN   1925.000000    NaN       NaN
# 25%               NaN              NaN   2013.000000    NaN       NaN
# 50%               NaN              NaN   2017.000000    NaN       NaN
# 75%               NaN              NaN   2018.000000    NaN       NaN
# max               NaN              NaN   2021.000000    NaN       NaN
#
#             listed_in                                        description
# count            7787                                               7787
# unique            492                                               7769
# top     Documentaries  Multiple women report their husbands as missin...
# freq              334                                                  3
# mean              NaN                                                NaN
# std               NaN                                                NaN
# min               NaN                                                NaN
# 25%               NaN                                                NaN
# 50%               NaN                                                NaN
# 75%               NaN                                                NaN
# max               NaN                                                NaN

# %%
data.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
# Fatiando os registros e retornando todas as colunas
data[16:700]
# Out:
#     show_id     type                       title  \
# 16      s17  TV Show                      Feb-09
# 17      s18    Movie                      22-Jul
# 18      s19    Movie                      15-Aug
# 19      s20    Movie                         '89
# 20      s21    Movie        ​​Kuch Bheege Alfaaz
# ..      ...      ...                         ...
# 695    s696    Movie                   Bad Match
# 696    s697    Movie                     Bad Rap
# 697    s698    Movie                   Bad Seeds
# 698    s699  TV Show  Badalte Rishton Ki Dastaan
# 699    s700    Movie                       Badha
#
#                             director  \
# 16                               NaN
# 17                   Paul Greengrass
# 18                Swapnaneel Jayakar
# 19                               NaN
# 20                              Onir
# ..                               ...
# 695               David Chirchirillo
# 696                    Salima Koroma
# 697                          Kheiron
# 698                              NaN
# 699  Sumitra Bhave, Sunil Sukthankar
#
#                                                   cast  \
# 16   Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
# 17   Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# 18   Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...
# 19                  Lee Dixon, Ian Wright, Paul Merson
# 20   Geetanjali Thapa, Zain Khan Durrani, Shray Rai...
# ..                                                 ...
# 695  Jack Cutmore-Scott, Lili Simmons, Brandon Scot...
# 696   Jonathan Park, Awkwafina, David Lee, Richard Lee
# 697  Kheiron, Catherine Deneuve, André Dussollier, ...
# 698  Additi Gupta, Sanjeeda Sheikh, Kiran Karmarkar...
# 699  Amruta Subhash, Rajesh More, Devika Daftardar,...
#
#                             country         date_added  release_year rating  \
# 16                              NaN     March 20, 2019          2018  TV-14
# 17   Norway, Iceland, United States   October 10, 2018          2018      R
# 18                            India     March 29, 2019          2019  TV-14
# 19                   United Kingdom       May 16, 2018          2017  TV-PG
# 20                            India  September 1, 2018          2018  TV-14
# ..                              ...                ...           ...    ...
# 695        Singapore, United States     March 11, 2018          2017  TV-MA
# 696           United States, Canada    August 21, 2017          2016  TV-MA
# 697                 France, Belgium  December 21, 2018          2018  TV-MA
# 698                           India      April 1, 2017          2013  TV-14
# 699                           India    January 1, 2018          2006  TV-14
#
#      duration                                         listed_in  \
# 16   1 Season                 International TV Shows, TV Dramas
# 17    144 min                                 Dramas, Thrillers
# 18    124 min              Comedies, Dramas, Independent Movies
# 19     87 min                                     Sports Movies
# 20    110 min  Dramas, Independent Movies, International Movies
# ..        ...                                               ...
# 695    83 min                                         Thrillers
# 696    83 min                   Documentaries, Music & Musicals
# 697   105 min            Comedies, Dramas, International Movies
# 698  1 Season                 International TV Shows, TV Dramas
# 699    91 min                      Dramas, International Movies
#
#                                            description
# 16   As a psychology professor faces Alzheimer's, h...
# 17   After devastating terror attacks in Norway, a ...
# 18   On India's Independence Day, a zany mishap in ...
# 19   Mixing old footage with interviews, this is th...
# 20   After accidentally connecting over the Interne...
# ..                                                 ...
# 695  A player who uses the internet to facilitate h...
# 696  Four young Asian-American rappers strive to ac...
# 697  Troubled by his past, a scam artist who runs a...
# 698  When a man is killed, his wife and his lover –...
# 699  A young woman who is suspected of practicing b...
#
# [684 rows x 12 columns]

# %%
# Retornando 1 coluna e fatiando
data['title'][16:700]
# Out:
# 16                         Feb-09
# 17                         22-Jul
# 18                         15-Aug
# 19                            '89
# 20           ​​Kuch Bheege Alfaaz
#                   ...
# 695                     Bad Match
# 696                       Bad Rap
# 697                     Bad Seeds
# 698    Badalte Rishton Ki Dastaan
# 699                         Badha
# Name: title, Length: 684, dtype: object

# %% [markdown]
# ## [Lendo planilhas xlsx](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html)

# %%
# imports
import pandas as pd

# %%
# Diretório com as planilhas

data_path = 'C:\\Users\\anton\\OneDrive\\Documentos\\Treinamento Cientista de Dados\\Python Aplicado a Big Data\\Aula 3 - 08032021 - Pandas\\sample-data\\xlsx\\'

# %% [markdown]
# #### a) Lendo arquivos xlsx passando o nome diretamente

# %%
dataframe = pd.read_excel(data_path+'Dataset.xlsx')
print(type(dataframe))
print()
print(dataframe)
print()
dataframe.describe()

# %% [markdown]
# #### b) Lendo arquivos xlsx acessando posição na lista criada anteriormente

# %%
df = pd.read_excel(data_path + files[1])
print(type(df))
print()
print(df)
print()
df.describe()

# %% [markdown]
# #### c) Lendo uma aba da planilha.
# **Parâmetro sheet_name**

# %%
df = pd.read_excel(data_path+'Road-Accident-Safety-Data-Guide-1979-2004.xls',sheet_name='Casualty Type')
df
# Out:
#     code                                              label
# 0      0                                         Pedestrian
# 1      1                                            Cyclist
# 2      2       Motorcycle 50cc and under rider or passenger
# 3      3      Motorcycle 125cc and under rider or passenger
# 4      4  Motorcycle over 125cc and up to 500cc rider or...
# 5      5           Motorcycle over 500cc rider or passenger
# 6      8                     Taxi/Private hire car occupant
# 7      9                                       Car occupant
# 8     10          Minibus (8 - 16 passenger seats) occupant
# 9     11      Bus or coach occupant (17 or more pass seats)
# 10    16                                        Horse rider
# 11    17                      Agricultural vehicle occupant
# 12    18                                      Tram occupant
# 13    19  Van / Goods vehicle (3.5 tonnes mgw or under) ...
# 14    20  Goods vehicle (over 3.5t. and under 7.5t.) occ...
# 15    21   Goods vehicle (7.5 tonnes mgw and over) occupant
# 16    22                             Mobility scooter rider
# 17    23             Electric motorcycle rider or passenger
# 18    90                             Other vehicle occupant
# 19    97         Motorcycle - unknown cc rider or passenger
# 20    98            Goods vehicle (unknown weight) occupant
# 21   103            Motorcycle - Scooter rider or passenger
# 22   104                      Motorcycle rider or passenger
# 23   105        Motorcycle - Combination rider or passenger
# 24   106           Motorcycle over 125cc rider or passenger
# 25   108        Taxi (excluding private hire cars) occupant
# 26   109         Car occupant (including private hire cars)
# 27   110                     Minibus/Motor caravan occupant
# 28   113           Goods vehicle (over 3.5 tonnes) occupant

# %% [markdown]
# #### d) Lendo uma planiha mantendo o formato dos dados da coluna.
# **Parâmetro dtype=object (Default = None)**
#
# Verificar coluna codigocliente

# %%
import pandas as pd
import openpyxl

# print('Diretório: ',os.getcwd())

# data_path = os.getcwd()

# path = 'G:\\Meu Drive\\Cursos e Treinamentos\\Cientista de Dados\\Treinamento Python\\Aplicado a Big Data\\Aula 3 - 08032021 - Pandas\\'
nomeplanilha = 'consulta receita sng siseg.xlsx'

# print('Nome da planilha: ',nomeplanilha)

df = pd.read_excel(nomeplanilha, dtype=object)
df
# Out:
#     Unnamed: 0  titulo documentofiscal   codigocliente  \
# 0            0  255777          421387  00000000000191
# 1            1  255777          421387  00000000000191
# 2            2  254633          420364  00000208000100
# 3            3  255796          421381  00000776000101
# 4            4  255672          421518  00068987000186
# ..         ...     ...             ...             ...
# 879        879  255654          421500  95213211000119
# 880        880  254732          420463  95783262000186
# 881        881  254592          420323  96479258000191
# 882        882  254967          420698  97467856000103
# 883        883  255768          421498  97489280000185
#
#                                       cliente  uf statusdotitulo  \
# 0                          BANCO DO BRASIL SA  DF           Pago
# 1                          BANCO DO BRASIL SA  DF           Pago
# 2                    BRB BANCO DE BRASILIA SA  DF           Pago
# 3      ITAU ADMINISTRADORA DE CONSORCIOS LTDA  SP           Pago
# 4    COOPERATIVA DE CREDITO SICOOB ARACREDI L  MG           Pago
# ..                                        ...  ..            ...
# 879  COOPERATIVA DE CRED POUP E INVES CAMINHO  RS           Pago
# 880  CARLESSI ADMINISTRADORA DE CONSORCIOS SC  SC           Pago
# 881  SCANIA ADMINISTRADORA DE CONSORCIOS LTDA  SP           Pago
# 882   RODOPARANA IMPLEMENTOS RODOVIARIOS LTDA  PR           Pago
# 883   C.ECO. CRED. M.PROF.SAUDE DA REGIAO SUL  BA           Pago
#
#                              empresaemitente          filial  \
# 0    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 1    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 2    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 3    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 4    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# ..                                       ...             ...
# 879  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 880  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 881  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 882  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
# 883  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  FENASEG MATRIZ
#
#                            empresarecebedora  ... codigodogrupo  \
# 0    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 1    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 2    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 3    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 4    FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# ..                                       ...  ...           ...
# 879  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 880  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 881  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 882  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
# 883  FED NAC EMP SEG  PRIV CAPIT E PREV COMP  ...          0106
#
#               grupoderecebimento contadofluxodecaixa  \
# 0    RECEITAS CONSULTAS/REG. SNG              030101
# 1    RECEITAS CONSULTAS/REG. SNG              030101
# 2    RECEITAS CONSULTAS/REG. SNG              030101
# 3    RECEITAS CONSULTAS/REG. SNG              030101
# 4    RECEITAS CONSULTAS/REG. SNG              030101
# ..                           ...                 ...
# 879  RECEITAS CONSULTAS/REG. SNG              030101
# 880  RECEITAS CONSULTAS/REG. SNG              030101
# 881  RECEITAS CONSULTAS/REG. SNG              030101
# 882  RECEITAS CONSULTAS/REG. SNG              030101
# 883  RECEITAS CONSULTAS/REG. SNG              030101
#
#                                          centrodecusto valorcentrocusto  \
# 0    F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...       116.118,17
# 1    F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...            65,12
# 2    F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...            71,26
# 3    F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...        63.065,10
# 4    F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...            71,26
# ..                                                 ...              ...
# 879  F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...           427,56
# 880  F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...           783,86
# 881  F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...         6.449,03
# 882  F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...         1.460,83
# 883  F331104002 - CONSULTAS SNG REGISTRO NÃO CUMULA...           391,93
#
#     valordecrescimo valoracrescimo quantidade valorunitario  \
# 0          2.322,38           0,00          1    116.118,17
# 1              1,30           0,00          1         65,12
# 2              0,00           0,00          1         71,26
# 3          8.829,12           0,00          1     63.065,10
# 4              1,43           0,00          1         71,26
# ..              ...            ...        ...           ...
# 879            8,55           0,00          1        427,56
# 880            0,00           0,00          1        783,86
# 881            0,00           0,00          1      6.449,03
# 882            0,00           0,00          1      1.460,83
# 883            7,84           0,00          1        391,93
#
#           descricaoitem
# 0    DESCRICAO GENERICA
# 1    DESCRICAO GENERICA
# 2    DESCRICAO GENERICA
# 3    DESCRICAO GENERICA
# 4    DESCRICAO GENERICA
# ..                  ...
# 879  DESCRICAO GENERICA
# 880  DESCRICAO GENERICA
# 881  DESCRICAO GENERICA
# 882  DESCRICAO GENERICA
# 883  DESCRICAO GENERICA
#
# [884 rows x 38 columns]

# %% [markdown]
# ## [Lendo arquivos CSV](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) ou arquivos de texto

# %%
# Armazene em uma variável o local onde estarão os arquivos que serão utilizados
data_path = 'C:\\Users\\anton\\OneDrive\\Documentos\\Treinamento Cientista de Dados\\Python Aplicado a Big Data\\Aula 3 - 08032021 - Pandas\\sample-data\\csv\\'

# Criando o dataframe
df_csv = pd.read_csv(data_path+'Arquivo-Treino.csv')

# Descreva o DF
print(df_csv.describe())
#print(df_csv)
print(df_csv.head())
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
