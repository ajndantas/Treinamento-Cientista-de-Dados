# %%
'''
    IS DIGIT
    Check if all the characters in the text are digits:
'''
str = 'antonio'
str.isdigit()
# Out:
# False

# %%
'''
    CAPITALIZE -> Coloca como maiúscula a primeira letra da string
'''
str.capitalize()
# Out:
# 'Antonio'

# %%
'''
    CENTER
'''
str.center(20,'#')
# Out:
# '######antonio#######'

# %%
'''
    COUNT
'''
# Conta quantas vezes str ocorre em uma string ou em uma subcadeia de strings se o índice inicial e o # final do índice forem fornecidos. 
str.count('o')

# %%
# Comentário de bloco 3x ' (Aspas simples)

'''
    ENDSWITH
    
    endswith (sufixo, beg = 0, end = len (string)) Determina se a string ou uma substring da string se  índice inicial e final do índice forem fornecidos) termina 
    com o sufixo; retorna true se sim e false caso contrário
'''
str.endswith('a')

# %%
'''
    FIND

    find (str, beg = 0 end = len (string)) Determina se str ocorre na string ou em uma subcadeia de strings se o índice inicial e final do índice receberem retornos. 
    
    Caso verdadeiro, retorna o índice referente a string desejada, do contrário, retorna -1 
'''

print(str.find('t'))
str.find('z')
# Out:
# 2
# -1

# %%
print(str)
'a' in str
# Out:
# antonio
# True

# %%
'''
    LEN
    
    Retorna o tamanho da string - Função
'''
len(str)

# %%
'''
    UPPER
    
    Converte a string para maiúscula
'''
str.upper()

# %%
'''
    LOWER
    
    Converte a string para mínuscula
'''
str.lower()

# %%
'''
    REPLACE

    Syntax
    string.replace(oldvalue, newvalue, count)

    Parameter Values
    Parameter	Description
    oldvalue	Required. The string to search for
    newvalue	Required. The string to replace the old value with
    count	Optional. A number specifying how many occurrences of the old value you                       want to replace. Default is all occurrences
'''
print(str.replace('z','gel'))

txt = 'Uma três pizzas de calabresa para três pessoas'
txt.replace('três','duas',1)
# Out:
# antonio
# 'Uma duas pizzas de calabresa para três pessoas'

# %%
'''
    SPLIT -> Gera Lista

    Syntax
    string.split(separator, maxsplit)

    Gera uma lista

    Parameter Values
    Parameter	Description
    separator	Optional. Specifies the separator to use when splitting the string. By default any whitespace is a separator
    maxsplit	Optional. Specifies how many splits to do. Default value is -1, which is "all occurrences"
'''
str = 'Antonio'
str1 = str + ' vai comprar pizza'
str2 = str + ', vai comprar sanduíche'
print(str1.split())
print(str2.split(','))

# Setting maxsplit
str3 = "apple#banana#cherry#orange"

# setting the maxsplit parameter to 1, will return a list with 2 elements!
print(str3.split("#",1))
print(str3.split("#",1)[0])

type(str3.split("#",1)[0])
# Out:
# ['Antonio', 'vai', 'comprar', 'pizza']
# ['Antonio', ' vai comprar sanduíche']
# ['apple', 'banana#cherry#orange']
# apple
# str

# %%
'''
    Fatiando string
    
    Não confundir posição com índice. Índice começa em 0, 
    posição, em 1
'''

str = 'Olá Mundo!'
print(str)

print(str[2:]) # Imprime a partir da 3 posição
print(str[2:5]) # Imprime do índice 2, com posição 5. 

print(str*2) # Imprime a string 2x
print(str + 'TESTANDO') # Concatena
# Out:
# Olá Mundo!
# á Mundo!
# á M
# Olá Mundo!Olá Mundo!
# Olá Mundo!TESTANDO

# %%
stringA = 'Hello World!'

print('Atualizando a minha string: ',stringA[:6] + 'código python !') # Sobrescreve a string anterior, com a nova, a partir da posição passada
    
print('Atualizando a minha string: ',stringA[:6],'código python !') # O mesmo que o de cima
    
print('Atualizando a minha string: ' + stringA[:6] + 'código python !') # O mesmo que o de cima
# Out:
# Atualizando a minha string:  Hello código python !
# Atualizando a minha string:  Hello  código python !
# Atualizando a minha string: Hello código python !

# %%
mes=4
print(str(int(mes)+1).replace('13','01').zfill(2))
# Out:
# 05
