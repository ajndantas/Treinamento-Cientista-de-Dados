# %% [markdown]
# ## Criando

# %%
# Nome : 'Florinda'
dici = {'Nome': None, 'idade': 37, 'Curso':'Pedagogia'}
print(dici)
# Out:
# {'Nome': None, 'idade': 37, 'Curso': 'Pedagogia'}

# %% [markdown]
# ### Usando construtor

# %%
thisdict = dict(name="John", age=36, country="Norway")
print(thisdict)
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %% [markdown]
# # Acessando

# %% [markdown]
# ### Usando dicionário['key']

# %%
print("dici['Nome']: ",dici['Nome'])
print("dici['idade']: ",dici['idade'])
# Out:
# dici['Nome']:  Florinda
# dici['idade']:  37

# %% [markdown]
# ### Usando get('key')

# %%
print(dici.get('idade'))
# Out:
# 37

# %%
print(dici.get('endereco')) # Acessando chave que não existe
# Out:
# None

# %% [markdown]
# ### Usando loop - Retorna apenas as chaves por linha

# %%
print(dici)

for v in dici:
    print(v)
# Out:
# {'Nome': None, 'idade': 37, 'Curso': 'Pedagogia'}
# Nome
# idade
# Curso

# %% [markdown]
# # Modificando </br>

# %%
print(dici)
dici['idade'] = 18
print(dici)

dici['idade'] = 18
print(dici)
# Out:
# {'Nome': 'Florinda', 'idade': 37, 'Curso': 'Pedagogia'}
# {'Nome': 'Florinda', 'idade': 18, 'Curso': 'Pedagogia'}
# {'Nome': 'Florinda', 'idade': 18, 'Curso': 'Pedagogia'}

# %% [markdown]
# # Criando nova chave, com novo valor

# %%
print(dici)
dici['Faculdade'] = 'Colação de Grau'
print(dici)
# Out:
# {'Nome': 'Florinda', 'idade': 18, 'Curso': 'Pedagogia'}
# {'Nome': 'Florinda', 'idade': 18, 'Curso': 'Pedagogia', 'Faculdade': 'Colação de Grau'}

# %% [markdown]
# ## Removendo elementos de um dicionário

# %%
print(dici)

del dici['Nome']

print(dici)
# Out:
# {'Nome': 'Florinda', 'idade': 18, 'Curso': 'Pedagogia', 'Faculdade': 'Colação de Grau'}
# {'idade': 18, 'Curso': 'Pedagogia', 'Faculdade': 'Colação de Grau'}

# %% [markdown]
# ## Retornando o objeto do dicionário. Pares chave, valor
# ### Método items()

# %%
print(dici.items())
print("Retorna o tipo de objeto: ", type(dici.items())) # Retorna o tipo do objeto
print("Retorna na forma de lista: ",list(dici.items())) # Retorna na forma de lista
# Out:
# dict_items([('idade', 18), ('Curso', 'Pedagogia'), ('Faculdade', 'Colação de Grau')])
# Retorna o tipo de objeto:  <class 'dict_items'>
# Retorna na forma de lista:  [('idade', 18), ('Curso', 'Pedagogia'), ('Faculdade', 'Colação de Grau')]

# %% [markdown]
# #### Em loop retorna linha a linha

# %%
print (dici.items())

for v in dici.items():
    print (v)
# Out:
# dict_items([('Nome', 'Florinda'), ('idade', 37), ('Curso', 'Pedagogia')])
# ('Nome', 'Florinda')
# ('idade', 37)
# ('Curso', 'Pedagogia')

# %% [markdown]
#  ## Retornando os valores

# %%
print(dici.values())
list(dici.values()) # Retorna os valores do dicionário
# Out:
# dict_values([None, 37, 'Pedagogia'])
# [None, 37, 'Pedagogia']

# %%
if None in list(dici.values()):
    print('Opa')
# Out:
# Opa

# %% [markdown]
# ## Retornando chaves

# %%
print(dici.keys())

print(list(dici.keys()))
# Out:
# dict_keys(['Nome', 'idade', 'Curso'])
# ['Nome', 'idade', 'Curso']

# %% [markdown]
# ## clear
# Limpando o dicionário

# %%
dici.clear() 
print(dici)

# %% [markdown]
# ## del
# Destruindo o dicionário

# %%
del dici 

print(dici)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-d45cde591868> in <module>
# ----> 1 del dici # Destruindo o dicionário
#
# NameError: name 'dici' is not defined

# %%
dici = {('Nome'): 'Florinda', 'idade': 37, 'Curso':'Pedagogia'}
dici['idade'] = 18

# Criando nova chave, com novo valor
dici['Faculdade'] = 'Colação de Grau'

# %%
dici[('Nome')] # Chamando a chave que é uma tupla
# Out:
# 'Florinda'

# %%
quadrados = {0:0,1:1,3:9,5:2}
all(quadrados) # Não podemos ter chave 0
# Out:
# False

# %% [markdown]
# ## Métodos de um Dicionário
# ### fromkeys()
# Permite substituir todos os valores de um dicionário, por um único valor, passando as chaves

# %%
# Métodos de dicionário
disciplinas = {}.fromkeys(['Sociologia','Historia','Geografia'],0)
print(disciplinas)
# Out:
# {'Sociologia': 0, 'Historia': 0, 'Geografia': 0}

# %% [markdown]
# ### sorted()

# %%
print(disciplinas)
print(sorted(disciplinas.keys())) # Fazendo o sorted direto no dicionário
# Out:
# {'Sociologia': 0, 'Historia': 0, 'Geografia': 0}
# ['Geografia', 'Historia', 'Sociologia']

# %% [markdown]
# ## Estrutura Dictionary Comprehension

# %%
# Dictionary Comprehension Structure
quadrado = {x : x*x for x in range(8)}
print(quadrado)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}

# %% [markdown]
# ### Com if

# %%
# Dictionary Comprehension Structure com if
quadrados_impares = {x : x*x for x in range(11) if x%2 == 1}
print(quadrados_impares)
# Out:
# {1: 1, 3: 9, 5: 25, 7: 49, 9: 81}
